# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 500)

# %%
# We use the bom.movie_gross.csv data to identify each movie's studio.
# We wanted to know the studio so we can identify trends within individual studios
bom = pd.read_csv('Data/bom.movie_gross.csv')

# We use the tn.movie_budgets.csv to identify each movie's budget and revenue figures.
tn = pd.read_csv('Data/tn.movie_budgets.csv')

# %%
# cleaning up an encoding issue for apostrophes
tn.movie = tn.movie.apply(lambda x: x.replace('â\x80\x99', "'"))

# Converting the money columns, which have values stored as strings due to dollar-signs and commas, to numbers.


def convert_currency_str_to_num(dataframe, column):
    dataframe[column] = dataframe[column].apply(lambda x: x.replace('$', ''))
    dataframe[column] = dataframe[column].apply(lambda x: x.replace(',', ''))
    dataframe[column] = dataframe[column].astype('float')


convert_currency_str_to_num(tn, 'production_budget')
convert_currency_str_to_num(tn, 'domestic_gross')
convert_currency_str_to_num(tn, 'worldwide_gross')

tn.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0        425000000.0     760507625.0     2.776345e+09
# 1        410600000.0     241063875.0     1.045664e+09
# 2        350000000.0      42762350.0     1.497624e+08
# 3        330600000.0     459005868.0     1.403014e+09
# 4        317000000.0     620181382.0     1.316722e+09

# %%
# Removing movies from before 2010 to conform with the time period in the other datasets
tn['year'] = tn.release_date.apply(lambda x: int(x[-4:]))
tn = tn.loc[tn.year >= 2010]

# %%
# Converting the release_date to a datetime object
tn['release_date'] = pd.to_datetime(tn.release_date)

# %%
tn.head()
# Out:
#    id release_date                                        movie  \
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# 5   6   2015-12-18         Star Wars Ep. VII: The Force Awakens
#
#    production_budget  domestic_gross  worldwide_gross  year
# 1        410600000.0     241063875.0     1.045664e+09  2011
# 2        350000000.0      42762350.0     1.497624e+08  2019
# 3        330600000.0     459005868.0     1.403014e+09  2015
# 4        317000000.0     620181382.0     1.316722e+09  2017
# 5        306000000.0     936662225.0     2.053311e+09  2015

# %%
bom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# This function returns True if the movie title has a 4-digit number/year within a parenthetical
# We found some titles in this dataset which had the year appended in a parenthetical,
# but that wasn't the case in the other datasets,
# so they would get excluded from an inner join on the titles.


def parenthetical_is_a_year(words):
    if words.find("(") != -1:
        new_words = words[(words.find("(")+1):(words.find(")"))]
        if (new_words.isdigit()) and (len(new_words) == 4):
            return True
        else:
            return False
    else:
        return False

# %%
# This function relies on parenthetical_is_a_year() to determine if there's a year appended to the title,
# and then removes the appended year if it exists


def remove_appended_yr_from_title(dataframe, column):
    dataframe[column] = dataframe[column].apply(
        lambda x: x[:(x.find("(")-1)] if parenthetical_is_a_year(x) else x)

# %%
remove_appended_yr_from_title(bom, 'title')

# %%
bom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                          Alice in Wonderland     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# This function removes punctuation from the titles and makes all characters lowercase.
# The intent is to remove styling that could inhibit a match when joining different datasets


def title_string_format_standardization(dataframe, column):
    dataframe[column] = dataframe[column].apply(lambda x: str(x).translate(str.maketrans('',
                                                                                         '',
                                                                                         string.punctuation)
                                                                           ).lower())

# %%
title_string_format_standardization(bom, 'title')

# %%
title_string_format_standardization(tn, 'movie')

# %%
bom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  toy story 3     BV     415000000.0
# 1                          alice in wonderland     BV     334200000.0
# 2  harry potter and the deathly hallows part 1     WB     296000000.0
# 3                                    inception     WB     292600000.0
# 4                          shrek forever after   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
tn.head()
# Out:
#    id release_date                                       movie  \
# 1   2   2011-05-20  pirates of the caribbean on stranger tides
# 2   3   2019-06-07                                dark phoenix
# 3   4   2015-05-01                      avengers age of ultron
# 4   5   2017-12-15             star wars ep viii the last jedi
# 5   6   2015-12-18          star wars ep vii the force awakens
#
#    production_budget  domestic_gross  worldwide_gross  year
# 1        410600000.0     241063875.0     1.045664e+09  2011
# 2        350000000.0      42762350.0     1.497624e+08  2019
# 3        330600000.0     459005868.0     1.403014e+09  2015
# 4        317000000.0     620181382.0     1.316722e+09  2017
# 5        306000000.0     936662225.0     2.053311e+09  2015

# %%
bom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2194 entries, 1 to 5780
# Data columns (total 7 columns):
# id                   2194 non-null int64
# release_date         2194 non-null datetime64[ns]
# movie                2194 non-null object
# production_budget    2194 non-null float64
# domestic_gross       2194 non-null float64
# worldwide_gross      2194 non-null float64
# year                 2194 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 137.1+ KB

# %%
print(bom.columns)
print(tn.columns)

# Only keeping pertinent columns of each dataframe.
bom = bom[['title', 'studio']]
tn = tn[['movie', 'release_date', 'production_budget', 'domestic_gross',
         'worldwide_gross']]

# Dropping the 5 rows from bom that have nulls since the count is so low
bom.dropna(inplace=True)
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')
# Index(['id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross', 'year'],
#       dtype='object')

# %%
len(bom.studio.unique())
# Out:
# 257

# %%
tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2194 entries, 1 to 5780
# Data columns (total 5 columns):
# movie                2194 non-null object
# release_date         2194 non-null datetime64[ns]
# production_budget    2194 non-null float64
# domestic_gross       2194 non-null float64
# worldwide_gross      2194 non-null float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 102.8+ KB

# %%
# Creating a foreign_gross column.
tn['foreign_gross'] = tn['worldwide_gross'] - tn['domestic_gross']
tn.head()
# Out:
#                                         movie release_date  production_budget  \
# 1  pirates of the caribbean on stranger tides   2011-05-20        410600000.0
# 2                                dark phoenix   2019-06-07        350000000.0
# 3                      avengers age of ultron   2015-05-01        330600000.0
# 4             star wars ep viii the last jedi   2017-12-15        317000000.0
# 5          star wars ep vii the force awakens   2015-12-18        306000000.0
#
#    domestic_gross  worldwide_gross  foreign_gross
# 1     241063875.0     1.045664e+09   8.046000e+08
# 2      42762350.0     1.497624e+08   1.070000e+08
# 3     459005868.0     1.403014e+09   9.440081e+08
# 4     620181382.0     1.316722e+09   6.965404e+08
# 5     936662225.0     2.053311e+09   1.116649e+09

# %%
sum(bom.duplicated())
# Out:
# 0

# %%
sum(tn.duplicated())
# Out:
# 0

# %%
# We did a left merge to explore the non-matches for a later inner join that will ultimately be analyzed.
# The previous data cleaning of the title strings was in response to this EDA.
studio_movie_performance_left = bom.merge(right=tn,
                                          how='left',
                                          left_on='title',
                                          right_on='movie')

# %%
sum(studio_movie_performance_left.movie.isna())
# Out:
# 1939

# %%
studio_movie_performance_left.sort_values('title').head(100)
# Out:
#                                                  title   studio  \
# 2394                               10 cloverfield lane     Par.
# 1038                                          10 years    Anch.
# 1830                             1000 times good night       FM
# 2282                                        1001 grams       KL
# 3222                                       102 not out     Sony
# 533                                             111111   Rocket
# 3161                                         12 strong       WB
# 1168                                  12 years a slave     FoxS
# 94                                           127 hours     FoxS
# 486                                       13 assassins    Magn.
# 2417          13 hours the secret soldiers of benghazi     Par.
# 3016                                        13 minutes      SPC
# 1849                                           13 sins     RTWC
# 1681                                         14 blades     RTWC
# 1039                                          17 girls   Strand
# 673                                               1911    Vari.
# 1866                               2 autumns 3 winters       FM
# 968                                 2 days in new york    Magn.
# 1181                                            2 guns     Uni.
# 1711                                          2 states      UTV
# 1314                              20 feet from stardom     RTWC
# 2163                                     20 once again       CJ
# 1715                               20000 days on earth    Drft.
# 3264               2001 a space odyssey 2018 rerelease       WB
# 2515                                20th century women      A24
# 1234                                       21 and over    Rela.
# 764                                     21 jump street     Sony
# 1268                                        22 bullets    Cdgm.
# 1502                                    22 jump street     Sony
# 3077                                               222    Magn.
# 1098                                    28 hotel rooms    Osci.
# 567                                                  3   Strand
# 2258                           3 12 minutes 10 bullets    Part.
# 1578                                    3 days to kill    Rela.
# 2989                                     3 generations    Wein.
# 2973                                         3 idiotas      PNT
# 444                                 30 minutes or less     Sony
# 1501                             300 rise of an empire       WB
# 967                                                360    Magn.
# 278                                      44 inch chest    Imag.
# 1101                             444 last day on earth      IFC
# 2060                                          45 years      IFC
# 2864                                    47 meters down    ENTMP
# 1176                                          47 ronin     Uni.
# 1062                                  5 broken cameras       KL
# 713                                      5 days of war    Anch.
# 2110                                      5 flights up      FCW
# 2184                                            5 to 7      IFC
# 448                                               5050     Sum.
# 2974                   6 below miracle on the mountain      MOM
# 1368                                           6 souls     RTWC
# 1780                                           7 boxes      BGP
# 3233                                 7 days in entebbe    Focus
# 632                                       7 khoon maaf      UTV
# 2092                                                71    RAtt.
# 143                                   71 into the fire       JS
# 2096                                          99 homes       BG
# 2820                              a bad moms christmas      STX
# 688                                   a beautiful life       CL
# 2458                                a beautiful planet     Imax
# 580                                      a better life     Sum.
# 2505                                   a bigger splash     FoxS
# 2158                               a borrowed identity   Strand
# 1395                          a bottle in the gaza sea       FM
# 2179                            a brilliant young mind    Gold.
# 3361                                         a ciambra      IFC
# 1696                                a coffee in berlin     MBox
# 2884                               a cure for wellness      Fox
# 466                                 a dangerous method      SPC
# 2802                                    a dogs purpose     Uni.
# 3272                                 a fantastic woman      SPC
# 1700                                  a five star life     MBox
# 2945                                       a gentleman      FIP
# 2965                                     a ghost story      A24
# 1762                  a girl walks home alone at night       KL
# 1435     a glimpse inside the mind of charles swan iii      A24
# 1148                            a good day to die hard      Fox
# 656                          a good old fashioned orgy    Gold.
# 1224                                   a haunted house      ORF
# 1614                                 a haunted house 2      ORF
# 1386                                       a hijacking    Magn.
# 2521                           a hologram for the king    RAtt.
# 2199               a journey through time with anthony       CL
# 973                                     a late quartet     EOne
# 1661                                  a letter to momo       GK
# 981                             a little bit of heaven      MNE
# 2032                                    a little chaos      FCW
# 1658                                   a long way down    Magn.
# 2530                                  a man called ove     MBox
# 2691                              a melody to remember       CJ
# 1554                 a million ways to die in the west     Uni.
# 2434                                   a monster calls    Focus
# 2722                   a monster with a thousand heads     MBox
# 1640                               a most violent year      A24
# 1597                                 a most wanted man    RAtt.
# 56                           a nightmare on elm street  WB (NL)
# 3370                                 a paris education       KL
# 2553                                     a perfect day      IFC
# 2166  a pigeon sat on a branch reflecting on existence    Magn.
# 2212             a poem is a naked person 2015 reissue     Jan.
#
#                                          movie release_date  \
# 2394                       10 cloverfield lane   2016-03-11
# 1038                                       NaN          NaT
# 1830                                       NaN          NaT
# 2282                                       NaN          NaT
# 3222                                       NaN          NaT
# 533                                        NaN          NaT
# 3161                                 12 strong   2018-01-19
# 1168                          12 years a slave   2013-10-18
# 94                                   127 hours   2010-11-05
# 486                                        NaN          NaT
# 2417  13 hours the secret soldiers of benghazi   2016-01-15
# 3016                                       NaN          NaT
# 1849                                   13 sins   2014-04-18
# 1681                                       NaN          NaT
# 1039                                       NaN          NaT
# 673                                        NaN          NaT
# 1866                                       NaN          NaT
# 968                                        NaN          NaT
# 1181                                    2 guns   2013-08-02
# 1711                                       NaN          NaT
# 1314                      20 feet from stardom   2013-06-14
# 2163                                       NaN          NaT
# 1715                                       NaN          NaT
# 3264                                       NaN          NaT
# 2515                                       NaN          NaT
# 1234                               21 and over   2013-03-01
# 764                             21 jump street   2012-03-16
# 1268                                       NaN          NaT
# 1502                            22 jump street   2014-06-13
# 3077                                       NaN          NaT
# 1098                                       NaN          NaT
# 567                                          3   2011-09-16
# 2258                                       NaN          NaT
# 1578                            3 days to kill   2014-02-21
# 2989                                       NaN          NaT
# 2973                                       NaN          NaT
# 444                         30 minutes or less   2011-08-12
# 1501                     300 rise of an empire   2014-03-07
# 967                                        NaN          NaT
# 278                                        NaN          NaT
# 1101                                       NaN          NaT
# 2060                                       NaN          NaT
# 2864                                       NaN          NaT
# 1176                                  47 ronin   2013-12-25
# 1062                                       NaN          NaT
# 713                              5 days of war   2011-08-19
# 2110                                       NaN          NaT
# 2184                                       NaN          NaT
# 448                                       5050   2011-09-30
# 2974                                       NaN          NaT
# 1368                                       NaN          NaT
# 1780                                       NaN          NaT
# 3233                                       NaN          NaT
# 632                                        NaN          NaT
# 2092                                       NaN          NaT
# 143                                        NaN          NaT
# 2096                                       NaN          NaT
# 2820                      a bad moms christmas   2017-11-01
# 688                                        NaN          NaT
# 2458                                       NaN          NaT
# 580                              a better life   2011-06-24
# 2505                                       NaN          NaT
# 2158                                       NaN          NaT
# 1395                                       NaN          NaT
# 2179                                       NaN          NaT
# 3361                                       NaN          NaT
# 1696                                       NaN          NaT
# 2884                                       NaN          NaT
# 466                         a dangerous method   2011-11-23
# 2802                            a dogs purpose   2017-01-27
# 3272                                       NaN          NaT
# 1700                                       NaN          NaT
# 2945                                       NaN          NaT
# 2965                             a ghost story   2017-07-07
# 1762                                       NaN          NaT
# 1435                                       NaN          NaT
# 1148                    a good day to die hard   2013-02-14
# 656                                        NaN          NaT
# 1224                           a haunted house   2013-01-11
# 1614                         a haunted house 2   2014-04-18
# 1386                                       NaN          NaT
# 2521                   a hologram for the king   2016-04-22
# 2199                                       NaN          NaT
# 973                                        NaN          NaT
# 1661                                       NaN          NaT
# 981                     a little bit of heaven   2012-05-04
# 2032                                       NaN          NaT
# 1658                                       NaN          NaT
# 2530                                       NaN          NaT
# 2691                                       NaN          NaT
# 1554         a million ways to die in the west   2014-05-30
# 2434                           a monster calls   2017-01-06
# 2722                                       NaN          NaT
# 1640                       a most violent year   2014-12-31
# 1597                         a most wanted man   2014-07-25
# 56                   a nightmare on elm street   2010-04-30
# 3370                                       NaN          NaT
# 2553                                       NaN          NaT
# 2166                                       NaN          NaT
# 2212                                       NaN          NaT
#
#       production_budget  domestic_gross  worldwide_gross  foreign_gross
# 2394          5000000.0      72082999.0      108286422.0     36203423.0
# 1038                NaN             NaN              NaN            NaN
# 1830                NaN             NaN              NaN            NaN
# 2282                NaN             NaN              NaN            NaN
# 3222                NaN             NaN              NaN            NaN
# 533                 NaN             NaN              NaN            NaN
# 3161         35000000.0      45819713.0       71118378.0     25298665.0
# 1168         20000000.0      56671993.0      181025343.0    124353350.0
# 94           18000000.0      18335230.0       60217171.0     41881941.0
# 486                 NaN             NaN              NaN            NaN
# 2417         50000000.0      52853219.0       69411370.0     16558151.0
# 3016                NaN             NaN              NaN            NaN
# 1849          4000000.0          9134.0          47552.0        38418.0
# 1681                NaN             NaN              NaN            NaN
# 1039                NaN             NaN              NaN            NaN
# 673                 NaN             NaN              NaN            NaN
# 1866                NaN             NaN              NaN            NaN
# 968                 NaN             NaN              NaN            NaN
# 1181         61000000.0      75612460.0      132493015.0     56880555.0
# 1711                NaN             NaN              NaN            NaN
# 1314          1000000.0       4946250.0        5892466.0       946216.0
# 2163                NaN             NaN              NaN            NaN
# 1715                NaN             NaN              NaN            NaN
# 3264                NaN             NaN              NaN            NaN
# 2515                NaN             NaN              NaN            NaN
# 1234         13000000.0      25682380.0       42195766.0     16513386.0
# 764          42000000.0     138447667.0      202812429.0     64364762.0
# 1268                NaN             NaN              NaN            NaN
# 1502         50000000.0     191719337.0      331333876.0    139614539.0
# 3077                NaN             NaN              NaN            NaN
# 1098                NaN             NaN              NaN            NaN
# 567           7200000.0         59774.0         295492.0       235718.0
# 2258                NaN             NaN              NaN            NaN
# 1578         28000000.0      30697999.0       38959900.0      8261901.0
# 2989                NaN             NaN              NaN            NaN
# 2973                NaN             NaN              NaN            NaN
# 444          28000000.0      37053924.0       40966716.0      3912792.0
# 1501        110000000.0     106580051.0      330780051.0    224200000.0
# 967                 NaN             NaN              NaN            NaN
# 278                 NaN             NaN              NaN            NaN
# 1101                NaN             NaN              NaN            NaN
# 2060                NaN             NaN              NaN            NaN
# 2864                NaN             NaN              NaN            NaN
# 1176        175000000.0      38362475.0      151716815.0    113354340.0
# 1062                NaN             NaN              NaN            NaN
# 713          12000000.0         17479.0          87793.0        70314.0
# 2110                NaN             NaN              NaN            NaN
# 2184                NaN             NaN              NaN            NaN
# 448           8000000.0      35016118.0       41334735.0      6318617.0
# 2974                NaN             NaN              NaN            NaN
# 1368                NaN             NaN              NaN            NaN
# 1780                NaN             NaN              NaN            NaN
# 3233                NaN             NaN              NaN            NaN
# 632                 NaN             NaN              NaN            NaN
# 2092                NaN             NaN              NaN            NaN
# 143                 NaN             NaN              NaN            NaN
# 2096                NaN             NaN              NaN            NaN
# 2820         28000000.0      72110659.0      127710550.0     55599891.0
# 688                 NaN             NaN              NaN            NaN
# 2458                NaN             NaN              NaN            NaN
# 580          10000000.0       1759252.0        1884251.0       124999.0
# 2505                NaN             NaN              NaN            NaN
# 2158                NaN             NaN              NaN            NaN
# 1395                NaN             NaN              NaN            NaN
# 2179                NaN             NaN              NaN            NaN
# 3361                NaN             NaN              NaN            NaN
# 1696                NaN             NaN              NaN            NaN
# 2884                NaN             NaN              NaN            NaN
# 466          20000000.0       5702083.0       14807531.0      9105448.0
# 2802         25000000.0      64321890.0      203671625.0    139349735.0
# 3272                NaN             NaN              NaN            NaN
# 1700                NaN             NaN              NaN            NaN
# 2945                NaN             NaN              NaN            NaN
# 2965           100000.0       1594798.0        2769782.0      1174984.0
# 1762                NaN             NaN              NaN            NaN
# 1435                NaN             NaN              NaN            NaN
# 1148         92000000.0      67349198.0      304249198.0    236900000.0
# 656                 NaN             NaN              NaN            NaN
# 1224          2500000.0      40041683.0       59922558.0     19880875.0
# 1614          4000000.0      17329487.0       21206861.0      3877374.0
# 1386                NaN             NaN              NaN            NaN
# 2521         35000000.0       4212494.0       11846010.0      7633516.0
# 2199                NaN             NaN              NaN            NaN
# 973                 NaN             NaN              NaN            NaN
# 1661                NaN             NaN              NaN            NaN
# 981          12500000.0         10011.0        1100287.0      1090276.0
# 2032                NaN             NaN              NaN            NaN
# 1658                NaN             NaN              NaN            NaN
# 2530                NaN             NaN              NaN            NaN
# 2691                NaN             NaN              NaN            NaN
# 1554         40000000.0      42720965.0       86778557.0     44057592.0
# 2434         43000000.0       3740823.0       46414530.0     42673707.0
# 2722                NaN             NaN              NaN            NaN
# 1640         20000000.0       5749134.0        8846875.0      3097741.0
# 1597         15000000.0      17237855.0       36068890.0     18831035.0
# 56           35000000.0      63075011.0      117729621.0     54654610.0
# 3370                NaN             NaN              NaN            NaN
# 2553                NaN             NaN              NaN            NaN
# 2166                NaN             NaN              NaN            NaN
# 2212                NaN             NaN              NaN            NaN

# %%
studio_movie_performance_left.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3387 entries, 0 to 3386
# Data columns (total 8 columns):
# title                3387 non-null object
# studio               3387 non-null object
# movie                1448 non-null object
# release_date         1448 non-null datetime64[ns]
# production_budget    1448 non-null float64
# domestic_gross       1448 non-null float64
# worldwide_gross      1448 non-null float64
# foreign_gross        1448 non-null float64
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 238.1+ KB

# %%
# Inner joining the studio and budget+revenue data sets to ensure we have a set of movies with a complete set of info.
studio_movie_performance_inner = bom.merge(right=tn,
                                           how='inner',
                                           left_on='title',
                                           right_on='movie')

# %%
studio_movie_performance_inner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1448 entries, 0 to 1447
# Data columns (total 8 columns):
# title                1448 non-null object
# studio               1448 non-null object
# movie                1448 non-null object
# release_date         1448 non-null datetime64[ns]
# production_budget    1448 non-null float64
# domestic_gross       1448 non-null float64
# worldwide_gross      1448 non-null float64
# foreign_gross        1448 non-null float64
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 101.8+ KB

# %%
imdb_titles = pd.read_csv('Exploration/imdb_df_join3.csv')

# %%
imdb_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 10 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146123 non-null object
# start_year         146144 non-null int64
# runtime_minutes    114405 non-null float64
# genres             146144 non-null object
# averagerating      73856 non-null float64
# numvotes           73856 non-null float64
# directors          140417 non-null object
# writers            110261 non-null object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 11.2+ MB

# %%
imdb_titles.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes  \
# 0        2013            175.0    Action,Crime,Drama            7.0      77.0
# 1        2019            114.0       Biography,Drama            7.2      43.0
# 2        2018            122.0                 Drama            6.9    4517.0
# 3        2018              NaN          Comedy,Drama            6.1      13.0
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5     119.0
#
#              directors                                  writers
# 0            nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 1            nm0002411                                      NaN
# 2            nm0000080                      nm0000080,nm0462648
# 3            nm0611531                                nm0347899
# 4  nm0765384,nm0749914                      nm1360635,nm0749914

# %%
len(set(imdb_titles.original_title))
# Out:
# 137774

# %%
# Creating subsets of the dataframe with the unique IMDb title ID (i.e. tconst).
# These are then concatenated and duplicates are removed.
# This provides a map between all potential IMDb titles and their unique IDs.
primary_titles = imdb_titles[['tconst', 'primary_title']]
original_titles = imdb_titles[['tconst', 'original_title']]
primary_titles.columns = ['tconst', 'title']
original_titles.columns = ['tconst', 'title']

# %%
imdb_titles_only = pd.concat([primary_titles, original_titles])

# %%
title_string_format_standardization(imdb_titles_only, 'title')

# %%
imdb_titles_only.head()
# Out:
#       tconst                            title
# 0  tt0063540                        sunghursh
# 1  tt0066787  one day before the rainy season
# 2  tt0069049       the other side of the wind
# 3  tt0069204                  sabse bada sukh
# 4  tt0100275         the wandering soap opera

# %%
imdb_titles_only.tail()
# Out:
#            tconst                                       title
# 146139  tt9916538                         kuambil lagi hatiku
# 146140  tt9916622  rodolpho teóphilo  o legado de um pioneiro
# 146141  tt9916706                             dankyavar danka
# 146142  tt9916730                                      6 gunn
# 146143  tt9916754               chico albuquerque  revelações

# %%
imdb_titles_only.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 292288 entries, 0 to 146143
# Data columns (total 2 columns):
# tconst    292288 non-null object
# title     292288 non-null object
# dtypes: object(2)
# memory usage: 6.7+ MB

# %%
# Removing duplicates.
imdb_titles_only = imdb_titles_only.loc[imdb_titles_only.duplicated() == False]
imdb_titles_only.dropna(inplace=True)

# %%
imdb_titles_only.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160557 entries, 0 to 146135
# Data columns (total 2 columns):
# tconst    160557 non-null object
# title     160557 non-null object
# dtypes: object(2)
# memory usage: 3.7+ MB

# %%
imdb_titles_only.reset_index(inplace=True)

# %%
imdb_titles_only.drop('index', axis=1, inplace=True)
imdb_titles_only.head()
# Out:
#       tconst                            title
# 0  tt0063540                        sunghursh
# 1  tt0066787  one day before the rainy season
# 2  tt0069049       the other side of the wind
# 3  tt0069204                  sabse bada sukh
# 4  tt0100275         the wandering soap opera

# %%
studio_movie_performance_inner.head()
# Out:
#                        title studio                      movie release_date  \
# 0                toy story 3     BV                toy story 3   2010-06-18
# 1        alice in wonderland     BV        alice in wonderland   2010-03-05
# 2                  inception     WB                  inception   2010-07-16
# 3        shrek forever after   P/DW        shrek forever after   2010-05-21
# 4  the twilight saga eclipse   Sum.  the twilight saga eclipse   2010-06-30
#
#    production_budget  domestic_gross  worldwide_gross  foreign_gross
# 0        200000000.0     415004880.0     1.068880e+09    653874642.0
# 1        200000000.0     334191110.0     1.025491e+09    691300000.0
# 2        160000000.0     292576195.0     8.355246e+08    542948447.0
# 3        165000000.0     238736787.0     7.562447e+08    517507886.0
# 4         68000000.0     300531751.0     7.061028e+08    405571077.0

# %%
# Joining the unique IMDb title ID (i.e. tconst) with the budget, revenue and studio data.
studio_movie_performance_inner_w_imdb = studio_movie_performance_inner.merge(right=imdb_titles_only,
                                                                             how='inner',
                                                                             left_on='title',
                                                                             right_on='title')

# %%
studio_movie_performance_inner_w_imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2077 entries, 0 to 2076
# Data columns (total 9 columns):
# title                2077 non-null object
# studio               2077 non-null object
# movie                2077 non-null object
# release_date         2077 non-null datetime64[ns]
# production_budget    2077 non-null float64
# domestic_gross       2077 non-null float64
# worldwide_gross      2077 non-null float64
# foreign_gross        2077 non-null float64
# tconst               2077 non-null object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 162.3+ KB

# %%
studio_movie_performance_inner_w_imdb.head()
# Out:
#                  title studio                movie release_date  \
# 0          toy story 3     BV          toy story 3   2010-06-18
# 1  alice in wonderland     BV  alice in wonderland   2010-03-05
# 2  alice in wonderland     BV  alice in wonderland   2010-03-05
# 3  alice in wonderland     BV  alice in wonderland   2010-03-05
# 4            inception     WB            inception   2010-07-16
#
#    production_budget  domestic_gross  worldwide_gross  foreign_gross  \
# 0        200000000.0     415004880.0     1.068880e+09    653874642.0
# 1        200000000.0     334191110.0     1.025491e+09    691300000.0
# 2        200000000.0     334191110.0     1.025491e+09    691300000.0
# 3        200000000.0     334191110.0     1.025491e+09    691300000.0
# 4        160000000.0     292576195.0     8.355246e+08    542948447.0
#
#       tconst
# 0  tt0435761
# 1  tt1014759
# 2  tt1926979
# 3  tt2049386
# 4  tt1375666

# %%
studio_movie_performance_inner_w_imdb.drop('movie', axis=1, inplace=True)

# %%
studio_movie_performance_inner_w_imdb.to_csv(
    'Exploration/studio_movie_performance_inner_w_imdb.csv', index=False)
